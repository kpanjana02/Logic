# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

# %%
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_test = x_test / 255.0
x_test = x_test[..., None]

  # should be (10000,)

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(x_train, y_train, epochs=5    )
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 963us/step - accuracy: 0.8512 - loss: 2.3211
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 959us/step - accuracy: 0.9018 - loss: 0.3905
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9240 - loss: 0.2922
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9339 - loss: 0.2548
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 947us/step - accuracy: 0.9414 - loss: 0.2309
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 970us/step - accuracy: 0.9447 - loss: 0.2117
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9484 - loss: 0.2057
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 990us/step - accuracy: 0.9498 - loss: 0.1953
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9528 - loss: 0.1936
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 981us/step - accuracy: 0.9535 - loss: 0.1902

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("test accuracy:",test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.1074 - loss: 2.4272
# test accuracy: 0.10740000009536743

# %%
from tensorflow.keras.preprocessing import image

img=image.load_img(r"C:\Users\User\Desktop\Machine\image.png", target_size=(28, 28), color_mode="grayscale")
img_array=image.img_to_array(img)

img_array = img_array /255.0

img_array = 1-img_array

img_array = img_array.reshape(1, 28, 28)

prediction = model.predict(img_array)
predicted_digit =np.argmax(prediction)

print("predicted digit",predicted_digit)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# predicted digit 8

# %%
from tensorflow.keras.datasets import mnist

(_, _), (x_test, y_test) = mnist.load_data()

x_test = x_test / 255.0
x_test = x_test[..., None]

print(y_test.shape)  # should be (10000,)
# Out:
# (10000,)
