# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# %%
#Load the dataset
df=pd.read_csv("hours.csv")
print("Data loaded successfully.Here are thr first 5 rows:")
print(df.head())
# Out:
# Data loaded successfully.Here are thr first 5 rows:
#    Hours  Marks
# 0      2     10
# 1      5     50
# 2      5     46
# 3      9     90
# 4      8     85

# %%
#Prepare the data
x=df.iloc[:, :-1].values #hours(attributes)
y=df.iloc[:, 1].values   #scores(labels)
#split into training and testing sets (80/20)
x_train, x_test,y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Data split into training and testing sets.")
# Out:
# Data split into training and testing sets.

# %%
regressor=LinearRegression()
regressor.fit(x_train, y_train)

print("Training complete")
# Out:
# Training complete

# %%
y_pred = regressor.predict(x_test)

mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

print(f"Mean Absolute Error: {mae:2f}")
print(f"R-Squared Score: {r2:2f}")
# Out:
# Mean Absolute Error: 13.058493
# R-Squared Score: 0.094577

# %%
line=regressor.coef_ *x + regressor.intercept_

plt.figure(figsize=(10,6))
plt.scatter(x,y,color="royalblue",edgecolors="black",s=100,label="Data Points")
plt.plot(x,line,color="crimson",linewidth=2,label="Regression Line")
plt.title("Linear Regression:Hours vs Scores",fontsize=15)
plt.xlabel("Hours Studied",fontsize=12)
plt.ylabel("Percentage Score",fontsize=12)
plt.legend()
plt.show()

# %%
hours = float(input("Enter hours"))
prediction=regressor.predict([[hours]])
print(f"Predicted score for{hours} hours of study: {prediction[0]:2f}")
# Out:
# Predicted score for9.0 hours of study: 84.401279
